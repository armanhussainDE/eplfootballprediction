# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
# %matplotlib inline


warnings.filterwarnings('ignore')

# %% [markdown]
# ### Obtaining our Dataset

# %%
EPL_predictions = pd.read_csv('EPLpredictions.csv')

# %%
EPL_predictions.head()
# Out:
#    Unnamed: 0  fixture_id  Shots on Goal  Shots off Goal  Total Shots  \
# 0           0      192867              3               5          NaN
# 1           1      192867              2               3          NaN
# 2           2      192868              3               7          NaN
# 3           3      192868              2               3          NaN
# 4           4      192869              5               5          NaN
#
#    Blocked Shots  Shots insidebox  Shots outsidebox  Fouls  Corner Kicks  ...  \
# 0            NaN              NaN               NaN      8            11  ...
# 1            NaN              NaN               NaN     12             7  ...
# 2            NaN              NaN               NaN     11             5  ...
# 3            NaN              NaN               NaN     11             2  ...
# 4            NaN              NaN               NaN     16             4  ...
#
#            status statusShort  elapsed  \
# ...

# %%
#Getting the number of rows and columns in our data

EPL_predictions.shape
# Out:
# (4650, 35)

# %%
#Finding out the column names and types of data in each column

EPL_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4650 entries, 0 to 4649
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        4650 non-null   int64
#  1   fixture_id        4650 non-null   int64
#  2   Shots on Goal     4650 non-null   int64
#  3   Shots off Goal    4650 non-null   int64
#  4   Total Shots       4458 non-null   float64
#  5   Blocked Shots     4456 non-null   float64
#  6   Shots insidebox   4458 non-null   float64
#  7   Shots outsidebox  4458 non-null   float64
#  8   Fouls             4650 non-null   int64
#  9   Corner Kicks      4650 non-null   int64
#  10  Offsides          4474 non-null   float64
#  11  Ball Possession   4650 non-null   object
#  12  Yellow Cards      4376 non-null   float64
#  13  Red Cards         718 non-null    float64
#  14  Goalkeeper Saves  4632 non-null   float64
#  15  Total passes      4458 non-null   float64
# ...

# %%
#Getting the number of missing values in our data

EPL_predictions.isnull().sum()
# Out:
# Unnamed: 0             0
# fixture_id             0
# Shots on Goal          0
# Shots off Goal         0
# Total Shots          192
# Blocked Shots        194
# Shots insidebox      192
# Shots outsidebox     192
# Fouls                  0
# Corner Kicks           0
# Offsides             176
# Ball Possession        0
# Yellow Cards         274
# Red Cards           3932
# Goalkeeper Saves      18
# Total passes         192
# Passes accurate      192
# Passes %             192
# league_id              0
# league                 0
# event_date             0
# event_timestamp        0
# firstHalfStart         0
# secondHalfStart        0
# round                  0
# status                 0
# statusShort            0
# elapsed                0
# venue                  0
# referee                0
# homeTeam               0
# awayTeam               0
# goalsHomeTeam          0
# goalsAwayTeam          0
# score                  0
# dtype: int64

# %%
EPL_predictions.head()
# Out:
#    Unnamed: 0  fixture_id  Shots on Goal  Shots off Goal  Total Shots  \
# 0           0      192867              3               5          NaN
# 1           1      192867              2               3          NaN
# 2           2      192868              3               7          NaN
# 3           3      192868              2               3          NaN
# 4           4      192869              5               5          NaN
#
#    Blocked Shots  Shots insidebox  Shots outsidebox  Fouls  Corner Kicks  ...  \
# 0            NaN              NaN               NaN      8            11  ...
# 1            NaN              NaN               NaN     12             7  ...
# 2            NaN              NaN               NaN     11             5  ...
# 3            NaN              NaN               NaN     11             2  ...
# 4            NaN              NaN               NaN     16             4  ...
#
#            status statusShort  elapsed  \
# ...
